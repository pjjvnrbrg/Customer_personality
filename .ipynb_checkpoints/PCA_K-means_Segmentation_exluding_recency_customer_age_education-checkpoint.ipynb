# %% [markdown]
# # Background
#
# The data was obtained from Kaggle (https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis) with a CC0: Public Domain license. The data was inspected, features were created/modified and outliers removed. The created features/modified were:
#
# Created:
# - Customer Age
# - Total Expenses
# - Seniority
# - Child Count (Number of Children)
# - Has Child (Boolean for children)
#
# Modified:
# - Marital Status
# - Education
#
# Outliers were removed using scatterplots and boxplots with visual inspection. The prepared data was pickled along with the features to be used for clustering in a list. Pearson correlations were also calculated and the following was determined:
#
# - Income vs Expenses are correlated positively (+0.83)
# - Children vs Income (-0.35) and Children vs Expenses (-0.5) are negativly correlated
#
# The rest show little to no correlation. PCA indicated we can remove recency and customer age.

# %% [markdown]
# # Goal
#
# Apply K-means and PCA to segment the data based on the features to use excluding recency and customer age

# %% [markdown]
# # Imports

# %%
# data tools
import numpy as np
import pandas as pd
import pickle as pkl


# inspection tools
# from IPython.core.display import HTML
# from dataprep.eda import plot, plot_correlation, create_report, plot_missing

# date handling
# import datetime
# from datetime import date

# graphing
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
sns.set()

# machine learning
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.mixture import GaussianMixture
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# # Functions

# %%
# Function to display informative elbow method for clusters

def test_clusters(X, random_state, max_clusters, metric='distortion'):
    model = KMeans(random_state=random_state, n_init=10, max_iter=300, tol=1e-04, init='k-means++')
    if metric == 'distortion':
        elb_visualiser = KElbowVisualizer(model, k=(1,max_clusters), metric=metric)
    else:
        elb_visualiser = KElbowVisualizer(model, k=(2,max_clusters), metric=metric)
    elb_visualiser.fit(X)
    return elb_visualiser.show()

# Function to display informative silhouette method for clusters

def silhouette_clusters(X, random_state, number_of_clusters):
    model = KMeans(n_clusters=number_of_clusters, random_state=random_state, n_init=10, max_iter=300, tol=1e-04, init='k-means++')
    
    sil_visualiser = SilhouetteVisualizer(model)
    sil_visualiser.fit(X)
    return sil_visualiser.show()

# Function to perform PCA analysis
def pca_analysis(X, num_components):
    if num_components == 'find':
        pca = PCA()
        pca.fit(X)
    else:
        pca = PCA(n_components=num_components)
        pca.fit(X)
    return pca

# function to get component loadings from PCA
def get_comp_loadings(pca_components, cols, index):
    df_pca_comp = pd.DataFrame(data = pca_components, columns=cols, index = index)
    return df_pca_comp

# %% [markdown]
# # Load Data

# %%
with open('customer_data_without_outliers.pickle', 'rb') as handle:
    dict = pkl.load(handle)

# %%
features = dict['cluster_features']

# %%
# Unpack the data
data = dict['data']

#  Select clustering features
segm_data = data[features].copy().drop(["Child_Count",'Customer_Age','Recency'], axis = 1)
features = segm_data.columns.tolist()
segm_data
# Out:
#           Education Marital_Status   Income  Total_Expenses  Seniority  \
# ID
# 5524   Postgraduate          Alone  58138.0            1617  25.333333
# 2174   Postgraduate          Alone  46344.0              27   7.000000
# 4141   Postgraduate         Couple  71613.0             776  13.633333
# 6182   Postgraduate         Couple  26646.0              53   7.866667
# 5324   Postgraduate         Couple  58293.0             422   8.600000
# ...             ...            ...      ...             ...        ...
# 10870  Postgraduate         Couple  61223.0            1341  15.933333
# 4001   Postgraduate         Couple  64014.0             444   3.866667
# 7270   Postgraduate          Alone  56981.0            1241   8.400000
# 8235   Postgraduate         Couple  69245.0             843   8.433333
# 9405   Postgraduate         Couple  52869.0             172  23.966667
#
#        Has_child
# ID
# 5524    No child
# 2174   Has child
# 4141    No child
# 6182   Has child
# 5324   Has child
# ...          ...
# 10870  Has child
# 4001   Has child
# 7270    No child
# 8235   Has child
# 9405   Has child
#
# [2203 rows x 6 columns]

# %%
# replace boolean versions for children, marital and education

segm_data_temp = segm_data.replace({'Postgraduate': 1,
                               'Undergraduate': 0,
                                'Alone': 0,
                                'Couple': 1,
                                'Has child': 1,
                                'No child': 0})
segm_data_temp
# Out:
#        Education  Marital_Status   Income  Total_Expenses  Seniority  \
# ID
# 5524           1               0  58138.0            1617  25.333333
# 2174           1               0  46344.0              27   7.000000
# 4141           1               1  71613.0             776  13.633333
# 6182           1               1  26646.0              53   7.866667
# 5324           1               1  58293.0             422   8.600000
# ...          ...             ...      ...             ...        ...
# 10870          1               1  61223.0            1341  15.933333
# 4001           1               1  64014.0             444   3.866667
# 7270           1               0  56981.0            1241   8.400000
# 8235           1               1  69245.0             843   8.433333
# 9405           1               1  52869.0             172  23.966667
#
#        Has_child
# ID
# 5524           0
# 2174           1
# 4141           0
# 6182           1
# 5324           1
# ...          ...
# 10870          1
# 4001           1
# 7270           0
# 8235           1
# 9405           1
#
# [2203 rows x 6 columns]

# %% [markdown]
# # Create dummy variables

# %%
# Get dummies on categorical data
df_dummies = pd.get_dummies(segm_data)
dummy_features = df_dummies.columns.tolist()

# %% [markdown]
# # Scale the data

# %%
# Use standard scaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_dummies)

# Normalisation
X_norm = normalize(X_scaled,norm='l2')

X = X_scaled.copy()

# %% [markdown]
# # PCA

# %%
# get the components
pca = pca_analysis(X, 'find')

#show the number of components
pca.components_.shape
# Out:
# (9, 9)

# %%
number_of_components = pca.components_.shape[0]

# %%
# Plot cumulative variance vs components

plt.figure(figsize=(12,9))
plt.plot(range(1, number_of_components+1), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle = '--')
plt.title("Explained Variance by components")
plt.xlabel("Components")
plt.ylabel("Cumulative Explained Varience")
# Out:
# Text(0, 0.5, 'Cumulative Explained Varience')

# %% [markdown]
# 70-80% Explained varience is a good benchmark, we can reduce the dimensionality to 3 components

# %%
Number_of_components_to_use = 3
pca = pca_analysis(X, Number_of_components_to_use)

# %% [markdown]
# ## PCA Results

# %%
pca_comp = get_comp_loadings(pca.components_, dummy_features, ['Component 1', 'Component 2', 'Component 3'])
pca_comp
# Out:
#                Income  Total_Expenses  Seniority  Education_Postgraduate  \
# Component 1  0.454882        0.495245   0.031702                0.125194
# Component 2 -0.048185        0.017573   0.048634               -0.660577
# Component 3 -0.104601       -0.083454   0.020063               -0.143332
#
#              Education_Undergraduate  Marital_Status_Alone  \
# Component 1                -0.125194              0.088652
# Component 2                 0.660577             -0.142140
# Component 3                 0.143332              0.685781
#
#              Marital_Status_Couple  Has_child_Has child  Has_child_No child
# Component 1              -0.088652            -0.499872            0.499872
# Component 2               0.142140            -0.202328            0.202328
# Component 3              -0.685781            -0.002573            0.002573

# %% [markdown]
# ### PCA pearson correlations to features

# %%
plt.figure(figsize=(12,6))
s = sns.heatmap(pca_comp,
               annot=True,
               cmap='RdBu',
               vmin=-1,
               vmax=1)
plt.yticks([0,1,2], ['Component 1', 'Component 2', 'Component 3'], rotation = 0, fontsize = 9)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - Component 1 is correlated to Income, Expenses and Children.
# - Component 2 is correlated to Education
# - Component 3 is correlated to Marital Status

# %%
# get the PCA scores
scores_pca = pca.transform(X)
scores_pca
# Out:
# array([[ 2.93841342, -0.12788483,  1.61136476],
#        [-0.93269939, -1.17573708,  1.82587983],
#        [ 2.11708325,  0.32587789, -1.241307  ],
#        ...,
#        [ 2.52369319, -0.25820542,  1.61906851],
#        [-0.11992861, -0.60089786, -1.26547221],
#        [-0.96036717, -0.47035101, -1.04320718]])

# %% [markdown]
# # Hierarchical Clustering

# %%
hier_clus = linkage(scores_pca, method='ward')

plt.figure(figsize=(12, 9))
plt.title("Hierachical Clustering")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hier_clus,
           truncate_mode='level',
           p=5,
           show_leaf_counts=False,
           no_labels=True,
           # color_threshold=0
           )
plt.show()

# %% [markdown]
# # K-means
# ## Choosing number of clusters

# %%
test_clusters(X=scores_pca, random_state=1, max_clusters=12, metric='distortion')
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
test_clusters(X=scores_pca, random_state=1, max_clusters=12, metric='silhouette')
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
silhouette_clusters(X=scores_pca, random_state=1, number_of_clusters=4)
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 2203 Samples in 4 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# ## Cluster selection
#
# The number of clusters to select seem to point to choosing 4 or 5 clusters. The elbow and dendrogram indicate 4 whilst the Silhoette score indicates 5. We could choose 5 clusters, however often a simpler model is best therefore we will choose 4.

# %%
# choose two clusters and fit
num_clusters = 4
kmeans_clus = KMeans(n_clusters=num_clusters, init='k-means++', random_state=1)
kmeans_clus.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ## Results PCA K-means

# %%
# Copying unscaled data and merging with PCA components for 4 clusters
segm_pca_kmeans_clus = pd.concat([df_dummies[dummy_features].reset_index(drop=False),
                                  pd.DataFrame(scores_pca)], axis=1)
segm_pca_kmeans_clus.columns.values[-3:] = ['Component 1',
                                            'Component 2',
                                            'Component 3',
                                            ]

# copy the labels from the models
segm_pca_kmeans_clus['Segment K-means PCA'] = kmeans_clus.labels_


# Calculate the means per cluster
segm_pca_kmeans_clus_means = segm_pca_kmeans_clus.groupby(
    ['Segment K-means PCA']).mean().reset_index(drop=False)


# Calculate the number of observations
segm_pca_kmeans_clus_means['N Obs'] = segm_pca_kmeans_clus[[
    'Segment K-means PCA', 'Income']].groupby(['Segment K-means PCA']).count()


# Calculate the percentage of observations
segm_pca_kmeans_clus_means['Percent Obs'] = (
    (segm_pca_kmeans_clus_means['N Obs']/segm_pca_kmeans_clus_means['N Obs'].sum())*100).round(2)

# %%
segm_pca_kmeans_clus_means.drop("ID", axis = 1, inplace=True)
segm_pca_kmeans_clus_means
# Out:
#    Segment K-means PCA        Income  Total_Expenses  Seniority  \
# 0                    0  74208.137421     1352.947146  14.821142
# 1                    1  45087.660232      384.569498  15.188353
# 2                    2  46592.007292      409.966667  14.849410
# 3                    3  41771.246032      409.984127  15.749603
#
#    Education_Postgraduate  Education_Undergraduate  Marital_Status_Alone  \
# 0                     1.0                      0.0              0.384778
# 1                     1.0                      0.0              1.000000
# 2                     1.0                      0.0              0.000000
# 3                     0.0                      1.0              0.325397
#
#    Marital_Status_Couple  Has_child_Has child  Has_child_No child  \
# 0               0.615222             0.012685            0.987315
# 1               0.000000             0.913127            0.086873
# 2               1.000000             0.963542            0.036458
# 3               0.674603             0.682540            0.317460
#
#    Component 1  Component 2  Component 3  N Obs  Percent Obs
# 0     2.769494     0.105270    -0.228233    473        21.47
# 1    -0.434929    -1.025439     1.807951    518        23.51
# 2    -0.864701    -0.481758    -1.071127    960        43.58
# 3    -1.010176     3.745526     0.792529    252        11.44

# %% [markdown]
# It seems that the clustering is mainly driven by the dummy variables, with only Cluster 0 having higher Income and Expenses than the rest.
#
# - Cluster 0 = Higher education, career focused, well-off
# - Cluster 1 = Higher education, single parents
# - Cluster 2 = Higher education, family oriented
# - Cluster 3 = Basic education

# %% [markdown]
# ## Rename the segments

# %%
segm_pca_kmeans_clus_means.rename({0: 'Higher education, career focused, well-off',
                                 1: 'Higher education, single parents',
                                 2: 'Higher education, family oriented',
                                 3: 'Basic education'})
# Out:
#                                             Segment K-means PCA        Income  \
# Higher education, career focused, well-off                    0  74208.137421
# Higher education, single parents                              1  45087.660232
# Higher education, family oriented                             2  46592.007292
# Basic education                                               3  41771.246032
#
#                                             Total_Expenses  Seniority  \
# Higher education, career focused, well-off     1352.947146  14.821142
# Higher education, single parents                384.569498  15.188353
# Higher education, family oriented               409.966667  14.849410
# Basic education                                 409.984127  15.749603
#
#                                             Education_Postgraduate  \
# Higher education, career focused, well-off                     1.0
# Higher education, single parents                               1.0
# Higher education, family oriented                              1.0
# Basic education                                                0.0
#
#                                             Education_Undergraduate  \
# Higher education, career focused, well-off                      0.0
# Higher education, single parents                                0.0
# Higher education, family oriented                               0.0
# Basic education                                                 1.0
#
#                                             Marital_Status_Alone  \
# Higher education, career focused, well-off              0.384778
# Higher education, single parents                        1.000000
# Higher education, family oriented                       0.000000
# Basic education                                         0.325397
#
#                                             Marital_Status_Couple  \
# Higher education, career focused, well-off               0.615222
# Higher education, single parents                         0.000000
# Higher education, family oriented                        1.000000
# Basic education                                          0.674603
#
#                                             Has_child_Has child  \
# Higher education, career focused, well-off             0.012685
# Higher education, single parents                       0.913127
# Higher education, family oriented                      0.963542
# Basic education                                        0.682540
#
#                                             Has_child_No child  Component 1  \
# Higher education, career focused, well-off            0.987315     2.769494
# Higher education, single parents                      0.086873    -0.434929
# Higher education, family oriented                     0.036458    -0.864701
# Basic education                                       0.317460    -1.010176
#
#                                             Component 2  Component 3  N Obs  \
# Higher education, career focused, well-off     0.105270    -0.228233    473
# Higher education, single parents              -1.025439     1.807951    518
# Higher education, family oriented             -0.481758    -1.071127    960
# Basic education                                3.745526     0.792529    252
#
#                                             Percent Obs
# Higher education, career focused, well-off        21.47
# Higher education, single parents                  23.51
# Higher education, family oriented                 43.58
# Basic education                                   11.44

# %%
# Map the segments onto observations

# %%
segm_data_temp['Labels'] = segm_pca_kmeans_clus['Segment K-means PCA'].map({0: 'Higher education, career focused, well-off',
                                                                            1: 'Higher education, single parents',
                                                                            2: 'Higher education, family oriented',
                                                                            3: 'Basic education'})

segm_pca_kmeans_clus['Labels'] = segm_pca_kmeans_clus['Segment K-means PCA'].map({0: 'Higher education, career focused, well-off',
                                                                                  1: 'Higher education, single parents',
                                                                                  2: 'Higher education, family oriented',
                                                                                  3: 'Basic education'})

# %% [markdown]
# # Plot the clusters

# %%
sns.pairplot(segm_data_temp, vars=features, hue='Labels', palette=sns.color_palette('hls',num_clusters))

# %%
sns.pairplot(segm_pca_kmeans_clus, vars=['Component 1', 'Component 2', 'Component 3'], hue='Labels', palette=sns.color_palette('hls',num_clusters))

# %% [markdown]
# # Conclusion
#
# The use of PCA has improved seperation by allowing us to cluster in the z-space. However the interpretability is lost somewhat despite the use of correlations.The x-space is no better resolved. Since the clustering is finding one cluster in Basic education and three in Higher education we can exclude it to find clusters in the other features.
