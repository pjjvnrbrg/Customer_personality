# %% [markdown]
# # Background
#
# The data was obtained from Kaggle (https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis) with a CC0: Public Domain license. The data was inspected, features were created/modified and outliers removed. The created features/modified were:
#
# Created:
# - Customer Age
# - Total Expenses
# - Seniority
# - Child Count (Number of Children)
# - Has Child (Boolean for children)
#
# Modified:
# - Marital Status
# - Education
#
# Outliers were removed using scatterplots and boxplots with visual inspection. The prepared data was pickled along with the features to be used for clustering in a list. Pearson correlations were also calculated and the following was determined:
#
# - Income vs Expenses are correlated positively (+0.83)
# - Children vs Income (-0.35) and Children vs Expenses (-0.5) are negativly correlated
#
# The rest show little to no correlation. PCA indicated we can remove recency, customer age and education. Marital status was also removed due to how it was effecting clustering. Has_child was swapped to child count instead of being a categorical feature. We therefore are not normalising the data, only scaling.

# %% [markdown]
# # Goal
#
# Apply K-means and PCA to segment the data based on the features to use excluding recency, customer age, education and marital status

# %% [markdown]
# # Imports

# %%
# data tools
import numpy as np
import pandas as pd
import pickle as pkl


# inspection tools
# from IPython.core.display import HTML
# from dataprep.eda import plot, plot_correlation, create_report, plot_missing

# date handling
# import datetime
# from datetime import date

# graphing
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
sns.set()

# machine learning
from sklearn.preprocessing import StandardScaler, normalize
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.mixture import GaussianMixture
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer

from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# import warnings
# warnings.filterwarnings('ignore')

# %% [markdown]
# # Functions

# %%
# Function to display informative elbow method for clusters

def test_clusters(X, random_state, max_clusters, metric='distortion'):
    model = KMeans(random_state=random_state, n_init=10, max_iter=300, tol=1e-04, init='k-means++')
    if metric == 'distortion':
        elb_visualiser = KElbowVisualizer(model, k=(1,max_clusters), metric=metric)
    else:
        elb_visualiser = KElbowVisualizer(model, k=(2,max_clusters), metric=metric)
    elb_visualiser.fit(X)
    return elb_visualiser.show()

# Function to display informative silhouette method for clusters

def silhouette_clusters(X, random_state, number_of_clusters):
    model = KMeans(n_clusters=number_of_clusters, random_state=random_state, n_init=10, max_iter=300, tol=1e-04, init='k-means++')
    
    sil_visualiser = SilhouetteVisualizer(model)
    sil_visualiser.fit(X)
    return sil_visualiser.show()

# Function to perform PCA analysis
def pca_analysis(X, num_components):
    if num_components == 'find':
        pca = PCA()
        pca.fit(X)
    else:
        pca = PCA(n_components=num_components)
        pca.fit(X)
    return pca

# function to get component loadings from PCA
def get_comp_loadings(pca_components, cols, index):
    df_pca_comp = pd.DataFrame(data = pca_components, columns=cols, index = index)
    return df_pca_comp

# %% [markdown]
# # Load Data

# %%
with open('customer_data_without_outliers.pickle', 'rb') as handle:
    dict = pkl.load(handle)

# %%
features = dict['cluster_features']

# %%
# Unpack the data
data = dict['data']

#  Select clustering features
segm_data = data[features].copy().drop(['Customer_Age','Recency', 'Education', 'Marital_Status', 'Has_child'], axis = 1)
features = segm_data.columns.tolist()
segm_data
# Out:
#         Income  Total_Expenses  Seniority  Child_Count
# ID
# 5524   58138.0            1617  25.333333            0
# 2174   46344.0              27   7.000000            2
# 4141   71613.0             776  13.633333            0
# 6182   26646.0              53   7.866667            1
# 5324   58293.0             422   8.600000            1
# ...        ...             ...        ...          ...
# 10870  61223.0            1341  15.933333            1
# 4001   64014.0             444   3.866667            3
# 7270   56981.0            1241   8.400000            0
# 8235   69245.0             843   8.433333            1
# 9405   52869.0             172  23.966667            2
#
# [2203 rows x 4 columns]

# %%
# replace boolean versions for children, marital and education

segm_data_temp = segm_data.replace({'Postgraduate': 1,
                               'Undergraduate': 0,
                                'Alone': 0,
                                'Couple': 1,
                                'Has child': 1,
                                'No child': 0})
segm_data_temp
# Out:
#         Income  Total_Expenses  Seniority  Child_Count
# ID
# 5524   58138.0            1617  25.333333            0
# 2174   46344.0              27   7.000000            2
# 4141   71613.0             776  13.633333            0
# 6182   26646.0              53   7.866667            1
# 5324   58293.0             422   8.600000            1
# ...        ...             ...        ...          ...
# 10870  61223.0            1341  15.933333            1
# 4001   64014.0             444   3.866667            3
# 7270   56981.0            1241   8.400000            0
# 8235   69245.0             843   8.433333            1
# 9405   52869.0             172  23.966667            2
#
# [2203 rows x 4 columns]

# %% [markdown]
# # Create dummy variables - not needed

# %%
# Get dummies on categorical data
# df_dummies = pd.get_dummies(segm_data)
# dummy_features = df_dummies.columns.tolist()

# %% [markdown]
# # Scale the data

# %%
# Use standard scaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(segm_data)

# Normalisation
X_norm = normalize(X_scaled,norm='l2')

X = X_norm.copy()

# %% [markdown]
# # PCA

# %%
# get the components
pca = pca_analysis(X, 'find')

#show the number of components
pca.components_.shape
# Out:
# (4, 4)

# %%
number_of_components = pca.components_.shape[0]

# %%
# Plot cumulative variance vs components

plt.figure(figsize=(12,9))
plt.plot(range(1, number_of_components+1), pca.explained_variance_ratio_.cumsum(), marker='o', linestyle = '--')
plt.title("Explained Variance by components")
plt.xlabel("Components")
plt.ylabel("Cumulative Explained Varience")
# Out:
# Text(0, 0.5, 'Cumulative Explained Varience')

# %% [markdown]
# 70-80% Explained varience is a good benchmark, we can reduce the dimensionality to 2 components

# %%
Number_of_components_to_use = 2
pca = pca_analysis(X, Number_of_components_to_use)

# %% [markdown]
# ## PCA Results

# %%
pca_comp = get_comp_loadings(pca.components_, features, ['Component 1', 'Component 2'])
pca_comp
# Out:
#                Income  Total_Expenses  Seniority  Child_Count
# Component 1  0.640008        0.670916   0.117223    -0.355698
# Component 2  0.187588       -0.041703  -0.979282    -0.063862

# %% [markdown]
# ### PCA pearson correlations to features

# %%
plt.figure(figsize=(12,6))
s = sns.heatmap(pca_comp,
               annot=True,
               cmap='RdBu',
               vmin=-1,
               vmax=1)
plt.yticks([0,1], ['Component 1', 'Component 2'], rotation = 0, fontsize = 9)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# - Component 1 is correlated to Income, Expenses and Children.
# - Component 2 is correlated to Seniority

# %%
# get the PCA scores
scores_pca = pca.transform(X)
scores_pca
# Out:
# array([[ 0.80342917, -0.5409009 ],
#        [-0.63690146,  0.51355553],
#        [ 0.81220719,  0.28073889],
#        ...,
#        [ 0.68018542,  0.54402434],
#        [ 0.55026823,  0.81079165],
#        [-0.32761594, -0.64943095]])

# %% [markdown]
# # Hierarchical Clustering

# %%
hier_clus = linkage(scores_pca, method='ward')

plt.figure(figsize=(12, 9))
plt.title("Hierachical Clustering")
plt.xlabel("Observations")
plt.ylabel("Distance")
dendrogram(hier_clus,
           truncate_mode='level',
           p=5,
           show_leaf_counts=False,
           no_labels=True,
           # color_threshold=0
           )
plt.show()

# %% [markdown]
# # K-means
# ## Choosing number of clusters

# %%
test_clusters(X=scores_pca, random_state=1, max_clusters=12, metric='distortion')
# Out:
# <AxesSubplot:title={'center':'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
test_clusters(X=scores_pca, random_state=1, max_clusters=12, metric='silhouette')
# Out:
# <AxesSubplot:title={'center':'Silhouette Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='silhouette score'>

# %%
silhouette_clusters(X=scores_pca, random_state=1, number_of_clusters=4)
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 2203 Samples in 4 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %% [markdown]
# ## Cluster selection
#
# The number of clusters to select seem to point to choosing 3 or 4 clusters. The elbow and dendrogram indicate 3 whilst the Silhoette score indicates 4. A simpler model is often best however, previous models suggested 4 clusters. It will ultimatly depend on the interpretability of the X-space. Let's choose for clusters for now and evalute at the end if we need to simplify the model.

# %%
# choose two clusters and fit
num_clusters = 4
kmeans_clus = KMeans(n_clusters=num_clusters, init='k-means++', random_state=1)
kmeans_clus.fit(scores_pca)
# Out:
# KMeans(n_clusters=4, random_state=1)

# %% [markdown]
# ## Results PCA K-means

# %%
# Copying unscaled data and merging with PCA components for 4 clusters
segm_pca_kmeans_clus = pd.concat([segm_data[features].reset_index(drop=False),
                                  pd.DataFrame(scores_pca)], axis=1)
segm_pca_kmeans_clus.columns.values[-2:] = ['Component 1',
                                            'Component 2',
                                            ]

# copy the labels from the models
segm_pca_kmeans_clus['Segment K-means PCA'] = kmeans_clus.labels_


# Calculate the means per cluster
segm_pca_kmeans_clus_means = segm_pca_kmeans_clus.groupby(
    ['Segment K-means PCA']).mean().reset_index(drop=False)


# Calculate the number of observations
segm_pca_kmeans_clus_means['N Obs'] = segm_pca_kmeans_clus[[
    'Segment K-means PCA', 'Income']].groupby(['Segment K-means PCA']).count()


# Calculate the percentage of observations
segm_pca_kmeans_clus_means['Percent Obs'] = (
    (segm_pca_kmeans_clus_means['N Obs']/segm_pca_kmeans_clus_means['N Obs'].sum())*100).round(2)

# %%
segm_pca_kmeans_clus_means.drop("ID", axis = 1, inplace=True)
segm_pca_kmeans_clus_means
# Out:
#    Segment K-means PCA        Income  Total_Expenses  Seniority  Child_Count  \
# 0                    0  35717.440000      206.600000  20.673000     1.241667
# 1                    1  72472.665904     1107.306636   9.208619     0.464531
# 2                    2  38441.655015      129.636778   9.115147     1.300912
# 3                    3  69517.539370     1265.513780  21.016864     0.564961
#
#    Component 1  Component 2  N Obs  Percent Obs
# 0    -0.486487    -0.540857    600        27.24
# 1     0.680131     0.549348    437        19.84
# 2    -0.616396     0.423671    658        29.87
# 3     0.787920    -0.382532    508        23.06

# %% [markdown]
# It seems that the clustering is mainly driven by the dummy variables, we now have seperation in the Income and expense features over the clusters.
#
# - Cluster 0 = Conservative, family oriented, old customer
# - Cluster 1 = Well-off, career-focused, young customer
# - Cluster 2 = Conservative, family oriented, young customer
# - Cluster 3 = Well-off, career-focused, old customer

# %% [markdown]
# ## Rename the segments

# %%
segm_pca_kmeans_clus_means.rename({0: 'Conservative, family oriented, old customer',
                                 1: 'Well-off, career-focused, young customer',
                                 2: 'Conservative, family oriented, young customer',
                                 3: 'Well-off, career-focused, old customer'})
# Out:
#                                                Segment K-means PCA  \
# Conservative, family oriented, old customer                      0
# Well-off, career-focused, young customer                         1
# Conservative, family oriented, young customer                    2
# Well-off, career-focused, old customer                           3
#
#                                                      Income  Total_Expenses  \
# Conservative, family oriented, old customer    35717.440000      206.600000
# Well-off, career-focused, young customer       72472.665904     1107.306636
# Conservative, family oriented, young customer  38441.655015      129.636778
# Well-off, career-focused, old customer         69517.539370     1265.513780
#
#                                                Seniority  Child_Count  \
# Conservative, family oriented, old customer    20.673000     1.241667
# Well-off, career-focused, young customer        9.208619     0.464531
# Conservative, family oriented, young customer   9.115147     1.300912
# Well-off, career-focused, old customer         21.016864     0.564961
#
#                                                Component 1  Component 2  \
# Conservative, family oriented, old customer      -0.486487    -0.540857
# Well-off, career-focused, young customer          0.680131     0.549348
# Conservative, family oriented, young customer    -0.616396     0.423671
# Well-off, career-focused, old customer            0.787920    -0.382532
#
#                                                N Obs  Percent Obs
# Conservative, family oriented, old customer      600        27.24
# Well-off, career-focused, young customer         437        19.84
# Conservative, family oriented, young customer    658        29.87
# Well-off, career-focused, old customer           508        23.06

# %%
# Map the segments onto observations

# %%
segm_data_temp['Labels'] = segm_pca_kmeans_clus['Segment K-means PCA'].map({0: 'Conservative, family oriented, old customer',
                                 1: 'Well-off, career-focused, young customer',
                                 2: 'Conservative, family oriented, young customer',
                                 3: 'Well-off, career-focused, old customer'})

segm_pca_kmeans_clus['Labels'] = segm_pca_kmeans_clus['Segment K-means PCA'].map({0: 'Conservative, family oriented, old customer',
                                 1: 'Well-off, career-focused, young customer',
                                 2: 'Conservative, family oriented, young customer',
                                 3: 'Well-off, career-focused, old customer'})

# %% [markdown]
# # Plot the clusters

# %%
sns.pairplot(segm_pca_kmeans_clus, vars=features, hue='Labels', palette=sns.color_palette('hls',num_clusters))

# %%
sns.pairplot(segm_pca_kmeans_clus, vars=['Component 1', 'Component 2'], hue='Labels', palette=sns.color_palette('hls',num_clusters))

# %% [markdown]
# # Conclusion
#
# The use of PCA has improved seperation by allowing us to cluster in the z-space. With the removal of certain features, the x-space is resolved. We have four clusters that appear to be intuitive in the "wealth" vs "seniority".
